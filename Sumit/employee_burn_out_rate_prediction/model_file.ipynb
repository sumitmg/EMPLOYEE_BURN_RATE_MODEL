# %%
# !pip install datatile
# Out:
# Collecting datatile
#   Downloading datatile-1.0.3-py3-none-any.whl (6.0 kB)
# Collecting traceml<1.1 (from datatile)
#   Downloading traceml-1.0.8-py3-none-any.whl (144 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 144.5/144.5 kB 6.4 MB/s eta 0:00:00
# Installing collected packages: traceml, datatile
# Successfully installed datatile-1.0.3 traceml-1.0.8
#
# [notice] A new release of pip is available: 23.1.1 -> 23.1.2
# [notice] To update, run: python -m pip install --upgrade pip

# %%
import pandas as pd
import numpy as np
from datatile.summary.df import DataFrameSummary

# %%
raw_data = pd.read_csv("Dataset/train.csv")

# %%
print(raw_data.shape)
raw_data.head()
# Out:
# (22750, 9)
#                 Employee ID Date of Joining  Gender Company Type  \
# 0  fffe32003000360033003200      2008-09-30  Female      Service
# 1      fffe3700360033003500      2008-11-30    Male      Service
# 2  fffe31003300320037003900      2008-03-10  Female      Product
# 3  fffe32003400380032003900      2008-11-03    Male      Service
# 4  fffe31003900340031003600      2008-07-24  Female      Service
#
#   WFH Setup Available  Designation  Resource Allocation  Mental Fatigue Score  \
# 0                  No          2.0                  3.0                   3.8
# 1                 Yes          1.0                  2.0                   5.0
# 2                 Yes          2.0                  NaN                   5.8
# 3                 Yes          1.0                  1.0                   2.6
# 4                  No          3.0                  7.0                   6.9
#
#    Burn Rate
# 0       0.16
# 1       0.36
# 2       0.49
# 3       0.20
# 4       0.52

# %%
dfs = DataFrameSummary(raw_data)
dfs.summary()
# Out:
# /home/codespace/.python/current/lib/python3.10/site-packages/datatile/summary/df.py:39: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   self.corr = df.corr()
#              Employee ID Date of Joining Gender Company Type  \
# count                NaN             NaN    NaN          NaN
# mean                 NaN             NaN    NaN          NaN
# std                  NaN             NaN    NaN          NaN
# min                  NaN             NaN    NaN          NaN
# 25%                  NaN             NaN    NaN          NaN
# 50%                  NaN             NaN    NaN          NaN
# 75%                  NaN             NaN    NaN          NaN
# max                  NaN             NaN    NaN          NaN
# counts             22750           22750  22750        22750
# uniques            22750             366      2            2
# missing                0               0      0            0
# missing_perc          0%              0%     0%           0%
# types             unique     categorical   bool         bool
#
#              WFH Setup Available Designation Resource Allocation  \
# count                        NaN     22750.0             21369.0
# mean                         NaN    2.178725            4.481398
# std                          NaN    1.135145            2.047211
# min                          NaN         0.0                 1.0
# 25%                          NaN         1.0                 3.0
# 50%                          NaN         2.0                 4.0
# 75%                          NaN         3.0                 6.0
# max                          NaN         5.0                10.0
# counts                     22750       22750               21369
# uniques                        2           6                  10
# missing                        0           0                1381
# missing_perc                  0%          0%               6.07%
# types                       bool     numeric             numeric
#
#              Mental Fatigue Score Burn Rate
# count                     20633.0   21626.0
# mean                     5.728188  0.452005
# std                      1.920839  0.198226
# min                           0.0       0.0
# 25%                           4.6      0.31
# 50%                           5.9      0.45
# 75%                           7.1      0.59
# max                          10.0       1.0
# counts                      20633     21626
# uniques                       101       101
# missing                      2117      1124
# missing_perc                9.31%     4.94%
# types                     numeric   numeric

# %%
# Null value treatment
raw_data['Resource Allocation'].fillna(value=raw_data['Resource Allocation'].median())
df_raw_data_clean = raw_data.dropna(axis=0)

df_raw_data_clean.shape
# Out:
# (18590, 9)

# %%
dfs = DataFrameSummary(df_raw_data_clean)
dfs.summary()
# Out:
# /home/codespace/.python/current/lib/python3.10/site-packages/datatile/summary/df.py:39: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   self.corr = df.corr()
#              Employee ID Date of Joining Gender Company Type  \
# count                NaN             NaN    NaN          NaN
# mean                 NaN             NaN    NaN          NaN
# std                  NaN             NaN    NaN          NaN
# min                  NaN             NaN    NaN          NaN
# 25%                  NaN             NaN    NaN          NaN
# 50%                  NaN             NaN    NaN          NaN
# 75%                  NaN             NaN    NaN          NaN
# max                  NaN             NaN    NaN          NaN
# counts             18590           18590  18590        18590
# uniques            18590             366      2            2
# missing                0               0      0            0
# missing_perc          0%              0%     0%           0%
# types             unique     categorical   bool         bool
#
#              WFH Setup Available Designation Resource Allocation  \
# count                        NaN     18590.0             18590.0
# mean                         NaN    2.179398            4.486552
# std                          NaN    1.133148            2.044848
# min                          NaN         0.0                 1.0
# 25%                          NaN         1.0                 3.0
# 50%                          NaN         2.0                 4.0
# 75%                          NaN         3.0                 6.0
# max                          NaN         5.0                10.0
# counts                     18590       18590               18590
# uniques                        2           6                  10
# missing                        0           0                   0
# missing_perc                  0%          0%                  0%
# types                       bool     numeric             numeric
#
#              Mental Fatigue Score Burn Rate
# count                     18590.0   18590.0
# mean                     5.732173  0.452444
# std                      1.920547  0.197848
# min                           0.0       0.0
# 25%                           4.6      0.32
# 50%                           5.9      0.45
# 75%                           7.1      0.59
# max                          10.0       1.0
# counts                      18590     18590
# uniques                       101       101
# missing                         0         0
# missing_perc                   0%        0%
# types                     numeric   numeric
